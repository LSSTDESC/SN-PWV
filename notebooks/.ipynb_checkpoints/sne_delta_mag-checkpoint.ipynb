# %% [markdown]
# # PWV effects on SN Magnitude
#
# This notebook demonstrates the effects of PWV absorption on the apparent magnitude of SNe.

# %%
import sys
sys.path.insert(0, '../')

import numpy as np
from matplotlib import pyplot as plt
from sn_analysis import modeling, sn_magnitudes, reference, plotting
from utils import register_decam_filters

register_decam_filters(force=True)

# %%
source = 'salt2-extended'
pwv_vals = np.arange(0, 10)
z_vals = np.arange(.01, 1.1, .05)
bands = 'decam_r', 'decam_i', 'decam_z'

# %% [markdown]
# ## Apparent magnitude
#
# We start by considering the direct impact of PWV absorbtion on simulated SN magnitudes. To do so, we simulate the apparent magnitude of a SNe Ia for multiple bands / redshifts / PWV concentrations.

# %%
tabulated_mag = sn_magnitudes.tabulate_mag(source, pwv_vals, z_vals, bands)
# Out:
# Tabulating Mag: 100%|██████████| 660/660 [01:22<00:00,  8.02it/s]

# %% [markdown]
# As the spectral template is redshifted, the bluer (brighter) portion of the spectra begins to enter the redder bands. We expect this to cause a temporary decrease in the apparent magnitude until the redshift becomes large enough that growing distance results in a monotonically increasing magnitude.

# %%
plotting.plot_magnitude(tabulated_mag, pwv_vals, z_vals)

# %% [markdown]
# This effect becomes more obvious when looking at the spectra template.

# %%
_ = plotting.plot_salt2_extended_template(np.arange(4000, 10000), [0, .5, 1], pwv=4)

# %% [markdown]
# To better understand the effects demonstrated above, we estimate the change in apparent magnitude due to PWV. Although we could measure this change relative to PWV=0, a more physically motivated approach is to use a fiducial atmosphere with a non-zero PWV component:
#
# $$\Delta m = m(\text{PWV}, z) - m(\text{PWV}_f, z)$$
#
# Note that the resulting value of $\Delta m$ is equivilent to the apparent magnitude normalized to the flux through the fiducial atmosphere.
#
# $$\Delta m = m(\text{PWV}, z) - m(\text{PWV}_f, z) = -2.5 log\left(\frac{f(\text{PWV}, z)}{f(\text{PWV}_f, z)}\right)$$
#
# We also determine the slope in the apparent magnitude as an estimate for how sensitive our simulated observations are to PWV fluxtuations.
#
# $$\frac{\Delta m}{\Delta \text{PWV}}(z) = \frac{m(\text{PWV}_2, z) - m(\text{PWV}_1, z)}{\text{PWV}_2 - \text{PWV}_1}$$
#
# where PWV$_1$ and PWV$_2$ are arbitrarily chosen PWV values that are equidistant to PWV$_f$. We take note of these PWV reference values in the following cell:

# %%
reference_pwv_config = reference.get_config_pwv_vals()
print(reference_pwv_config)
# Out:
# {'reference_pwv': 4.0, 'slope_start': 2.0, 'slope_end': 6.0}

# %% [markdown]
# Next we tabulate values for $\Delta m$ and $\frac{\Delta m}{\Delta \text{PWV}}(z)$.

# %%
fiducial_mag = sn_magnitudes.tabulate_fiducial_mag(
        source, z_vals, bands, reference_pwv_config)

tabulated_delta_mag, tabulated_slope = sn_magnitudes.calc_delta_mag(
    tabulated_mag, fiducial_mag, reference_pwv_config)
# Out:
# Tabulating Mag: 100%|██████████| 198/198 [00:23<00:00,  8.30it/s]

# %%
_ = plotting.plot_pwv_mag_effects(
    pwv_vals, 
    z_vals, 
    tabulated_delta_mag, 
    tabulated_slope, 
    bands)

# %% [markdown]
# In practice flux values are calibrated relative to a reference star. To understand how PWV effects SNe fluxes under these conditions, we normalize the SNe and Reference star flux to their respective fluxes through the fiducial atmosphere and take the difference (Normalized SNe - normalized reference star).

# %%
def calibrate_to_reference(delta_mag, slope, pwv_vals):
    
    assert delta_mag.keys() == slope.keys()
    reference_pwv_config = reference.get_config_pwv_vals()
    
    delta_mag_ref = {}
    slope_ref = {}
    for band in delta_mag:
        
        delta_mag_ref[band] = reference.subtract_ref_star(
            band, delta_mag[band], pwv_vals)
        
        slope_ref[band] = reference.subtract_ref_star_slope(
            band, slope[band], reference_pwv_config)
        
    return delta_mag_ref, slope_ref

# %%
reference_pwv_config = reference.get_config_pwv_vals()
tabulated_delta_mag_ref = reference.subtract_ref_star(tabulated_delta_mag, pwv_vals)
tabulated_slope_ref = reference.subtract_ref_star_slope(tabulated_slope, reference_pwv_config)

# %%
_ = plotting.plot_pwv_mag_effects(
    pwv_vals, 
    z_vals, 
    tabulated_delta_mag_ref, 
    tabulated_slope_ref, 
    bands)

# %% [markdown]
# ## 5. $\Delta m$ With Fitting
#
# We determine the change in apparent magnitude by simulating light-currves with PWV effects and then fitting a model without a PWV component.

# %%
# Realize simulations of light-curves
observations = modeling.create_observations_table()
light_curves = list(modeling.iter_lcs(observations, source, pwv_vals, z_vals))
reference_pwv_config = reference.get_config_pwv_vals()

# Fit light curves
vparams = ['x0', 'x1', 'c']
fitted_mag, fitted_params = sn_magnitudes.fit_mag(
        source, light_curves, vparams, pwv_vals, z_vals, bands)

# Get fiducial mag (uncalibrated)
fitted_fiducial_mag, fitted_fiducial_params = sn_magnitudes.fit_fiducial_mag(
        source, observations, vparams, z_vals, bands, reference_pwv_config)

fitted_delta_mag = {}
fitted_slope = {}
for band in bands:
    band_mag = fitted_mag[band]
    fiducial_mag = fitted_fiducial_mag[band]
    
    fitted_fiducial_dict = {
        'reference_pwv': [0],
        'slope_start': fitted_fiducial_mag[band][1],
        'slope_end': fitted_fiducial_mag[band][2]
    }
    
    fitted_delta_mag[band], fitted_slope[band] = sn_magnitudes.calc_delta_mag(
        band_mag, fitted_fiducial_dict, reference_pwv_config)
# Out:
# Light-Curves:  26%|██▌       | 57/220 [00:33<01:36,  1.68it/s]

# %%
fig, axes = plotting.plot_pwv_mag_effects(
    pwv_vals, 
    z_vals, 
    fitted_delta_mag, 
    fitted_slope, 
    default_bands)

axes[0][0].set_ylim(9.5, 11.5)

# %% [markdown]
# Next we add in the alpha and beta parameters from the fit.

# %%
# Determine calibrated magnitude from fits
calibrated_delta_mag = {}
calibrated_slope = {}
for band in bands:
    calibrated_mag = sn_magnitudes.calibrate_mag(
        default_source, fitted_mag[band], fitted_params[band])

    # Get fiducial mag (calibrated)
    calibrated_fiducial_mag = sn_magnitudes.calibrate_mag(
        default_source, fitted_fiducial_mag[band], fitted_fiducial_params[band])

    calibrated_fiducial_dict = {
        'reference_pwv': calibrated_fiducial_mag[0],
        'slope_start': calibrated_fiducial_mag[1],
        'slope_end': calibrated_fiducial_mag[2]
    }

    calibrated_delta_mag[band], calibrated_slope[band] = sn_magnitudes.calc_delta_mag(
        calibrated_mag, calibrated_fiducial_dict, reference_pwv_config)

# %%
plotting.plot_pwv_mag_effects(
    default_pwv, 
    default_z, 
    calibrated_delta_mag, 
    calibrated_slope, 
    default_bands)

# %%
plt_bands = {b: v[..., 3] for b, v in fitted_params.items()}
plotting.plot_pwv_mag_effects(
    default_pwv, 
    default_z, 
    plt_bands, 
    calibrated_slope, 
    default_bands)

# %%
plt_bands = {b: v[..., 4] for b, v in fitted_params.items()}
plotting.plot_pwv_mag_effects(
    default_pwv, 
    default_z, 
    plt_bands, 
    calibrated_slope, 
    default_bands)

# %%
import sncosmo
sncosmo.Model(default_source).param_names

# %% [markdown]
# - Examin fixed stretch and fixed color
# - Try fixed pwv or z
# - Reach out to helena to help with first year
